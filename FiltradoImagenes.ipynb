# %%
#Se importan librerías importantes

from PIL import Image
import requests

from PIL import UnidentifiedImageError

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Se carga el datset
df = pd.read_csv("/content/image-Sentiment-polarity-DFE.csv")

# %%
df['imageurl'][0]
# Out:
# 'http://farm1.staticflickr.com/20/71235476_310366f395.jpg'

# %%
im = Image.open(requests.get(df['imageurl'][1], stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F45859EA650>

# %%
 df
# Out:
#         _unit_id  ...  which_of_these_sentiment_scores_does_the_above_image_fit_into_best_gold_reason
# 0      694550568  ...                       He is smiling. => happy, joy
# 1      694550569  ...                   A beautiful scenery. => serenity
# 2      694550570  ...                They look serious. => sadness, fear
# 3      694550571  ...                        A cute puppy. => happy, joy
# 4      694550572  ...                  She looks fun. => fun, joy, happy
# ...          ...  ...                                                ...
# 15608  694566363  ...                                                NaN
# 15609  694566364  ...                                                NaN
# 15610  694566365  ...                                                NaN
# 15611  694566366  ...                                                NaN
# 15612  694566367  ...                                                NaN
#
# [15613 rows x 10 columns]

# %%
#Se filtra el dataset para que solo queden las imagenes con links funcionales.

for i in range(len(df)):
  try:
    Image.open(requests.get(df['imageurl'][i], stream=True).raw)
    print(i)
  except UnidentifiedImageError as e:
    df = df.drop([i])
    continue
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 9454
# 9455
# 9456
# 9458
# 9459
# 9461
# 9462
# 9465
# 9467
# 9468
# 9469
# 9470
# 9472
# 9473
# 9474
# 9476
# 9477
# 9478
# 9479
# 9480
# 9481
# 9482
# 9484
# 9485
# 9486
# 9487
# 9489
# 9490
# 9491
# 9492
# 9493
# 9494
# 9495
# 9496
# 9497
# 9499
# 9500
# 9502
# 9503
# 9508
# 9509
# 9510
# 9511
# 9513
# 9514
# 9515
# 9516
# 9517
# 9518
# 9519
# 9520
# 9521
# 9522
# 9523
# 9525
# 9526
# 9528
# 9532
# 9535
# 9539
# 9540
# 9541
# 9542
# 9545
# 9546
# 9547
# 9549
# 9550
# 9551
# 9552
# 9553
# 9555
# 9556
# 9557
# 9558
# 9559
# 9560
# 9562
# 9563
# 9564
# 9566
# 9567
# 9568
# 9569
# 9570
# 9571
# 9572
# 9573
# 9575
# 9576
# 9577
# 9578
# 9579
# 9580
# 9581
# 9582
# 9583
# 9584
# 9585
# 9586
# 9587
# 9588
# 9589
# 9591
# 9592
# 9593
# 9594
# 9595
# 9596
# 9598
# 9599
# 9600
# 9601
# 9602
# 9603
# 9604
# 9605
# 9606
# 9607
# 9609
# 9610
# 9611
# 9612
# 9613
# 9615
# 9617
# 9618
# 9619
# 9620
# 9621
# 9622
# 9624
# 9625
# ...

# %%
df
# Out:
#         _unit_id  ...  which_of_these_sentiment_scores_does_the_above_image_fit_into_best_gold_reason
# 0      694550568  ...                       He is smiling. => happy, joy
# 1      694550569  ...                   A beautiful scenery. => serenity
# 2      694550570  ...                They look serious. => sadness, fear
# 3      694550571  ...                        A cute puppy. => happy, joy
# 4      694550572  ...                  She looks fun. => fun, joy, happy
# ...          ...  ...                                                ...
# 15604  694566359  ...                                                NaN
# 15607  694566362  ...                                                NaN
# 15608  694566363  ...                                                NaN
# 15609  694566364  ...                                                NaN
# 15610  694566365  ...                                                NaN
#
# [12597 rows x 10 columns]

# %%
#Se descarga el dataset arreglado.
df.to_excel("/content/output.xlsx")

# %%
df
# Out:
#         _unit_id  ...  which_of_these_sentiment_scores_does_the_above_image_fit_into_best_gold_reason
# 0      694550568  ...                       He is smiling. => happy, joy
# 1      694550569  ...                   A beautiful scenery. => serenity
# 2      694550570  ...                They look serious. => sadness, fear
# 3      694550571  ...                        A cute puppy. => happy, joy
# 4      694550572  ...                  She looks fun. => fun, joy, happy
# ...          ...  ...                                                ...
# 15608  694566363  ...                                                NaN
# 15609  694566364  ...                                                NaN
# 15610  694566365  ...                                                NaN
# 15611  694566366  ...                                                NaN
# 15612  694566367  ...                                                NaN
#
# [15613 rows x 10 columns]
